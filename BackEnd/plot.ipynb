# %%
import pandas as pd
from run import run
sample_data = "Sample-Data.csv"

# %%
df = pd.read_csv(sample_data, index_col="Period")
# run("Moving Average", df, n = 9)
# run("Regression", df)
run("Exponential Smoothing", df, alpha = 0.2)
df = pd.read_csv('out.csv', index_col="Period")
df
# Out:
#         Demand  Forecast   |e|       e^2   %\e
# Period
# 09-Apr   31616     31616     0         0   0.0
# 09-May   33098     31616  1482   2196324   4.0
# 09-Jun   31780     31912   132     17424   0.0
# 09-Jul   27186     31886  4700  22090000  17.0
# 09-Aug   27286     30946  3660  13395600  13.0
# ...        ...       ...   ...       ...   ...
# 16-Jan   10846     13022  2176   4734976  20.0
# 16-Feb    9064     12587  3523  12411529  39.0
# 16-Mar   10626     11882  1256   1577536  12.0
# 16-Apr    7158     11631  4473  20007729  62.0
# 16-May    7558     10736  3178  10099684  42.0
#
# [86 rows x 5 columns]

# %%
lines = df.plot.line(y=['Demand', 'Forecast'])

# %%
from Errors import calculate_errors
calculate_errors(df)
# Out:
# MAD is 2517.0 MSE is 9566220.0 MAPE is 14.0
