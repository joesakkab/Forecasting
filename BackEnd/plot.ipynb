# %%
import pandas as pd
from run import run
sample_data = "Sample-Data.csv"

# %%
df = pd.read_csv(sample_data, index_col="Period")
# run("Moving Average", df, n = 9)
# run("Regression", df)
# run("Exponential Smoothing", df, column_name="Forecast", alpha = 0.2, start = 0)
run("Holts Method", df, alpha = 0.2, beta = 0.15, season=21)
df = pd.read_csv('out.csv', index_col="Period")
df
# Out:
# c:\Users\joesa\Desktop\Code\Forecasting\BackEnd\HoltsMethod.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['S_t'][season - 1] = a + b * (season - 1)
# c:\Users\joesa\Desktop\Code\Forecasting\BackEnd\HoltsMethod.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['G_t'][season - 1] = b
#         Demand   i     i*D_i      Forecast           S_t         G_t
# Period
# 09-Apr   31616   1   31616.0      0.000000           NaN         NaN  \
# 09-May   33098   2   66196.0      0.000000           NaN         NaN
# 09-Jun   31780   3   95340.0      0.000000           NaN         NaN
# ...

# %%
lines = df.plot.line(y=['Demand', 'Forecast'])

# %%
from Errors import calculate_errors
calculate_errors(df)
# Out:
# MAD is 8274.0 MSE is 204229660.0 MAPE is 32.0
